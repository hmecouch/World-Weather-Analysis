# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
latitudes = np.random.uniform(-90, 90, size = 2000)
longitudes = np.random.uniform(-180, 180, size = 2000)
# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(latitudes, longitudes)
lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 725

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_country = city_weather["sys"]["country"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        description = city_weather["weather"][0]["description"]
        
        # Append the city information to the city_data list
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | jamestown
# Processing Record 2 of Set 1 | barrow
# Processing Record 3 of Set 1 | kahului
# Processing Record 4 of Set 1 | cape town
# Processing Record 5 of Set 1 | talara
# Processing Record 6 of Set 1 | mahebourg
# Processing Record 7 of Set 1 | hualmay
# Processing Record 8 of Set 1 | busselton
# Processing Record 9 of Set 1 | comodoro rivadavia
# Processing Record 10 of Set 1 | karkaralinsk
# City not found. Skipping...
# Processing Record 11 of Set 1 | klaksvik
# Processing Record 12 of Set 1 | lorengau
# Processing Record 13 of Set 1 | grindavik
# Processing Record 14 of Set 1 | hammerfest
# Processing Record 15 of Set 1 | tezu
# Processing Record 16 of Set 1 | nikolskoye
# Processing Record 17 of Set 1 | bathsheba
# Processing Record 18 of Set 1 | cairns
# Processing Record 19 of Set 1 | katsuura
# Processing Record 20 of Set 1 | havoysund
# Processing Record 21 of Set 1 | juneau
# Processing Record 22 of Set 1 | yenagoa
# Processing Record 23 of Set 1 | geraldton
# Processing Record 24 of Set 1 | mataura
# Processing Record 25 of Set 1 | narsaq
# Processing Record 26 of Set 1 | huarmey
# Processing Record 27 of Set 1 | semirom
# Processing Record 28 of Set 1 | port alfred
# Processing Record 29 of Set 1 | xai-xai
# Processing Record 30 of Set 1 | madaoua
# Processing Record 31 of Set 1 | santa cruz
# Processing Record 32 of Set 1 | russkaya polyana
# Processing Record 33 of Set 1 | pacific grove
# Processing Record 34 of Set 1 | cherskiy
# Processing Record 35 of Set 1 | ushuaia
# Processing Record 36 of Set 1 | atuona
# Processing Record 37 of Set 1 | camana
# Processing Record 38 of Set 1 | saint anthony
# Processing Record 39 of Set 1 | butaritari
# Processing Record 40 of Set 1 | hermanus
# Processing Record 41 of Set 1 | ahuimanu
# Processing Record 42 of Set 1 | mecca
# Processing Record 43 of Set 1 | eirunepe
# Processing Record 44 of Set 1 | umzimvubu
# City not found. Skipping...
# Processing Record 45 of Set 1 | taoudenni
# Processing Record 46 of Set 1 | castro
# Processing Record 47 of Set 1 | bluff
# Processing Record 48 of Set 1 | tumannyy
# City not found. Skipping...
# Processing Record 49 of Set 1 | hilo
# Processing Record 50 of Set 1 | upernavik
# Processing Record 1 of Set 2 | fortuna
# Processing Record 2 of Set 2 | georgetown
# Processing Record 3 of Set 2 | vaini
# Processing Record 4 of Set 2 | ostrovnoy
# Processing Record 5 of Set 2 | saint-philippe
# Processing Record 6 of Set 2 | kavieng
# Processing Record 7 of Set 2 | viligili
# City not found. Skipping...
# Processing Record 8 of Set 2 | touros
# Processing Record 9 of Set 2 | hamilton
# Processing Record 10 of Set 2 | palabuhanratu
# City not found. Skipping...
# Processing Record 11 of Set 2 | hobart
# Processing Record 12 of Set 2 | kara-tyube
# Processing Record 13 of Set 2 | tasiilaq
# Processing Record 14 of Set 2 | sorland
# Processing Record 15 of Set 2 | atambua
# Processing Record 16 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 17 of Set 2 | east london
# Processing Record 18 of Set 2 | torbay
# Processing Record 19 of Set 2 | mar del plata
# Processing Record 20 of Set 2 | yellowknife
# Processing Record 21 of Set 2 | camacha
# Processing Record 22 of Set 2 | ca mau
# Processing Record 23 of Set 2 | nelson bay
# Processing Record 24 of Set 2 | avarua
# Processing Record 25 of Set 2 | chuy
# Processing Record 26 of Set 2 | yabelo
# Processing Record 27 of Set 2 | punta arenas
# Processing Record 28 of Set 2 | guerrero negro
# Processing Record 29 of Set 2 | mezen
# Processing Record 30 of Set 2 | yar-sale
# Processing Record 31 of Set 2 | nguru
# Processing Record 32 of Set 2 | paradwip
# City not found. Skipping...
# Processing Record 33 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 34 of Set 2 | arraial do cabo
# Processing Record 35 of Set 2 | broken hill
# Processing Record 36 of Set 2 | egvekinot
# Processing Record 37 of Set 2 | mana
# Processing Record 38 of Set 2 | flin flon
# Processing Record 39 of Set 2 | rio grande
# Processing Record 40 of Set 2 | kapaa
# Processing Record 41 of Set 2 | longlac
# City not found. Skipping...
# Processing Record 42 of Set 2 | clyde river
# Processing Record 43 of Set 2 | bredasdorp
# Processing Record 44 of Set 2 | albany
# Processing Record 45 of Set 2 | henties bay
# Processing Record 46 of Set 2 | santa vitoria do palmar
# Processing Record 47 of Set 2 | uvinza
# Processing Record 48 of Set 2 | salmas
# Processing Record 49 of Set 2 | chumikan
# Processing Record 50 of Set 2 | verkhnevilyuysk
# Processing Record 1 of Set 3 | ancud
# Processing Record 2 of Set 3 | pundaguitan
# Processing Record 3 of Set 3 | coahuayana
# Processing Record 4 of Set 3 | imeni poliny osipenko
# Processing Record 5 of Set 3 | poso
# Processing Record 6 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 7 of Set 3 | orizona
# Processing Record 8 of Set 3 | det udom
# Processing Record 9 of Set 3 | saskylakh
# Processing Record 10 of Set 3 | neryungri
# Processing Record 11 of Set 3 | sirohi
# Processing Record 12 of Set 3 | porto novo
# Processing Record 13 of Set 3 | khatanga
# Processing Record 14 of Set 3 | norman wells
# Processing Record 15 of Set 3 | lasa
# Processing Record 16 of Set 3 | kolpashevo
# Processing Record 17 of Set 3 | kruisfontein
# Processing Record 18 of Set 3 | pozhva
# Processing Record 19 of Set 3 | tromso
# Processing Record 20 of Set 3 | galle
# Processing Record 21 of Set 3 | merauke
# Processing Record 22 of Set 3 | ginowan
# Processing Record 23 of Set 3 | thompson
# Processing Record 24 of Set 3 | los llanos de aridane
# Processing Record 25 of Set 3 | kibaya
# Processing Record 26 of Set 3 | provideniya
# Processing Record 27 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 28 of Set 3 | tuktoyaktuk
# Processing Record 29 of Set 3 | yelkhovka
# Processing Record 30 of Set 3 | oparino
# Processing Record 31 of Set 3 | husavik
# Processing Record 32 of Set 3 | cayenne
# Processing Record 33 of Set 3 | cauquenes
# Processing Record 34 of Set 3 | borova
# Processing Record 35 of Set 3 | margate
# Processing Record 36 of Set 3 | new london
# Processing Record 37 of Set 3 | biasca
# Processing Record 38 of Set 3 | terney
# Processing Record 39 of Set 3 | komsomolskiy
# Processing Record 40 of Set 3 | ilinskiy
# Processing Record 41 of Set 3 | berlevag
# Processing Record 42 of Set 3 | hasaki
# Processing Record 43 of Set 3 | catamarca
# Processing Record 44 of Set 3 | skagastrond
# City not found. Skipping...
# Processing Record 45 of Set 3 | broome
# Processing Record 46 of Set 3 | pisco
# Processing Record 47 of Set 3 | manggar
# Processing Record 48 of Set 3 | rawson
# Processing Record 49 of Set 3 | marathon
# Processing Record 50 of Set 3 | chudovo
# Processing Record 1 of Set 4 | pevek
# Processing Record 2 of Set 4 | esperance
# Processing Record 3 of Set 4 | rikitea
# Processing Record 4 of Set 4 | deputatskiy
# Processing Record 5 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 6 of Set 4 | kemijarvi
# Processing Record 7 of Set 4 | vardo
# Processing Record 8 of Set 4 | teahupoo
# Processing Record 9 of Set 4 | sukhoy log
# Processing Record 10 of Set 4 | oistins
# Processing Record 11 of Set 4 | puerto ayora
# Processing Record 12 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 13 of Set 4 | caravelas
# Processing Record 14 of Set 4 | raudeberg
# Processing Record 15 of Set 4 | opuwo
# Processing Record 16 of Set 4 | labutta
# City not found. Skipping...
# Processing Record 17 of Set 4 | praia da vitoria
# Processing Record 18 of Set 4 | qaanaaq
# Processing Record 19 of Set 4 | marsa matruh
# Processing Record 20 of Set 4 | victoria
# Processing Record 21 of Set 4 | homer
# Processing Record 22 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 23 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 24 of Set 4 | najran
# Processing Record 25 of Set 4 | sarlat-la-caneda
# Processing Record 26 of Set 4 | san antonio
# Processing Record 27 of Set 4 | yeppoon
# Processing Record 28 of Set 4 | parabel
# Processing Record 29 of Set 4 | popondetta
# Processing Record 30 of Set 4 | carnarvon
# Processing Record 31 of Set 4 | ponta do sol
# Processing Record 32 of Set 4 | new norfolk
# Processing Record 33 of Set 4 | dikson
# Processing Record 34 of Set 4 | vestmannaeyjar
# Processing Record 35 of Set 4 | nanortalik
# Processing Record 36 of Set 4 | labuhan
# Processing Record 37 of Set 4 | matara
# Processing Record 38 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 39 of Set 4 | hithadhoo
# Processing Record 40 of Set 4 | eregli
# Processing Record 41 of Set 4 | bonnyville
# Processing Record 42 of Set 4 | kholmogory
# Processing Record 43 of Set 4 | luderitz
# Processing Record 44 of Set 4 | huicungo
# Processing Record 45 of Set 4 | daru
# Processing Record 46 of Set 4 | halden
# Processing Record 47 of Set 4 | pokhara
# Processing Record 48 of Set 4 | haines junction
# Processing Record 49 of Set 4 | koumac
# Processing Record 50 of Set 4 | srikakulam
# Processing Record 1 of Set 5 | mandalgovi
# Processing Record 2 of Set 5 | pauini
# Processing Record 3 of Set 5 | kavaratti
# Processing Record 4 of Set 5 | central point
# Processing Record 5 of Set 5 | coari
# Processing Record 6 of Set 5 | vitim
# Processing Record 7 of Set 5 | doraha
# Processing Record 8 of Set 5 | northam
# Processing Record 9 of Set 5 | hongjiang
# Processing Record 10 of Set 5 | san patricio
# Processing Record 11 of Set 5 | tafresh
# Processing Record 12 of Set 5 | logansport
# Processing Record 13 of Set 5 | carmen
# Processing Record 14 of Set 5 | nantucket
# Processing Record 15 of Set 5 | tzucacab
# Processing Record 16 of Set 5 | bossembele
# City not found. Skipping...
# Processing Record 17 of Set 5 | marmora
# Processing Record 18 of Set 5 | kandi
# Processing Record 19 of Set 5 | moron
# Processing Record 20 of Set 5 | sao filipe
# Processing Record 21 of Set 5 | maputo
# Processing Record 22 of Set 5 | asau
# Processing Record 23 of Set 5 | mount gambier
# Processing Record 24 of Set 5 | urucuca
# Processing Record 25 of Set 5 | faanui
# Processing Record 26 of Set 5 | aklavik
# Processing Record 27 of Set 5 | yaan
# Processing Record 28 of Set 5 | bayir
# Processing Record 29 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 30 of Set 5 | cuenca
# Processing Record 31 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 32 of Set 5 | airai
# Processing Record 33 of Set 5 | crotone
# Processing Record 34 of Set 5 | sao joao da barra
# Processing Record 35 of Set 5 | campo formoso
# Processing Record 36 of Set 5 | kodiak
# Processing Record 37 of Set 5 | port hardy
# Processing Record 38 of Set 5 | port elizabeth
# Processing Record 39 of Set 5 | burns lake
# Processing Record 40 of Set 5 | hami
# Processing Record 41 of Set 5 | raga
# Processing Record 42 of Set 5 | soligalich
# Processing Record 43 of Set 5 | iqaluit
# Processing Record 44 of Set 5 | alofi
# Processing Record 45 of Set 5 | lykhivka
# Processing Record 46 of Set 5 | koforidua
# Processing Record 47 of Set 5 | sinkat
# City not found. Skipping...
# Processing Record 48 of Set 5 | yelanskiy
# Processing Record 49 of Set 5 | thunder bay
# Processing Record 50 of Set 5 | portland
# Processing Record 1 of Set 6 | kiunga
# Processing Record 2 of Set 6 | lloydminster
# Processing Record 3 of Set 6 | conde
# Processing Record 4 of Set 6 | bengkulu
# Processing Record 5 of Set 6 | kijang
# Processing Record 6 of Set 6 | kalmunai
# Processing Record 7 of Set 6 | praia
# Processing Record 8 of Set 6 | zhigansk
# Processing Record 9 of Set 6 | dali
# Processing Record 10 of Set 6 | taburi
# City not found. Skipping...
# Processing Record 11 of Set 6 | saldanha
# Processing Record 12 of Set 6 | japura
# Processing Record 13 of Set 6 | olinda
# Processing Record 14 of Set 6 | brae
# Processing Record 15 of Set 6 | savannah bight
# Processing Record 16 of Set 6 | chokurdakh
# Processing Record 17 of Set 6 | sinnamary
# Processing Record 18 of Set 6 | lagoa
# Processing Record 19 of Set 6 | saint-pierre
# Processing Record 20 of Set 6 | helong
# Processing Record 21 of Set 6 | mayo
# Processing Record 22 of Set 6 | flinders
# Processing Record 23 of Set 6 | bojnurd
# Processing Record 24 of Set 6 | ascension
# Processing Record 25 of Set 6 | carnduff
# Processing Record 26 of Set 6 | boguchany
# Processing Record 27 of Set 6 | samarskoye
# Processing Record 28 of Set 6 | palmer
# Processing Record 29 of Set 6 | lavrentiya
# Processing Record 30 of Set 6 | atar
# Processing Record 31 of Set 6 | longyearbyen
# Processing Record 32 of Set 6 | lagos
# Processing Record 33 of Set 6 | artyk
# City not found. Skipping...
# Processing Record 34 of Set 6 | sterling
# Processing Record 35 of Set 6 | ponta delgada
# Processing Record 36 of Set 6 | grand centre
# City not found. Skipping...
# Processing Record 37 of Set 6 | mon
# Processing Record 38 of Set 6 | vila franca do campo
# Processing Record 39 of Set 6 | pangody
# Processing Record 40 of Set 6 | sitka
# Processing Record 41 of Set 6 | namibe
# Processing Record 42 of Set 6 | faya
# Processing Record 43 of Set 6 | ibra
# Processing Record 44 of Set 6 | katobu
# Processing Record 45 of Set 6 | wasilla
# Processing Record 46 of Set 6 | linqiong
# Processing Record 47 of Set 6 | ilebo
# Processing Record 48 of Set 6 | fairbanks
# Processing Record 49 of Set 6 | aykhal
# Processing Record 50 of Set 6 | oranjestad
# Processing Record 1 of Set 7 | del rio
# Processing Record 2 of Set 7 | vao
# Processing Record 3 of Set 7 | nome
# Processing Record 4 of Set 7 | ravar
# Processing Record 5 of Set 7 | buala
# Processing Record 6 of Set 7 | mirnyy
# Processing Record 7 of Set 7 | bondo
# Processing Record 8 of Set 7 | dunedin
# Processing Record 9 of Set 7 | tazmalt
# Processing Record 10 of Set 7 | kysyl-syr
# Processing Record 11 of Set 7 | hihifo
# City not found. Skipping...
# Processing Record 12 of Set 7 | zeya
# Processing Record 13 of Set 7 | benicarlo
# Processing Record 14 of Set 7 | severo-kurilsk
# Processing Record 15 of Set 7 | codrington
# Processing Record 16 of Set 7 | baykit
# Processing Record 17 of Set 7 | bambous virieux
# Processing Record 18 of Set 7 | salinas
# Processing Record 19 of Set 7 | abrau-dyurso
# Processing Record 20 of Set 7 | shuyskoye
# Processing Record 21 of Set 7 | sobolevo
# Processing Record 22 of Set 7 | kambove
# Processing Record 23 of Set 7 | sistranda
# Processing Record 24 of Set 7 | ilhabela
# Processing Record 25 of Set 7 | tura
# Processing Record 26 of Set 7 | amatlan
# City not found. Skipping...
# Processing Record 27 of Set 7 | bereda
# Processing Record 28 of Set 7 | algiers
# Processing Record 29 of Set 7 | barawe
# City not found. Skipping...
# Processing Record 30 of Set 7 | ormara
# Processing Record 31 of Set 7 | muisne
# Processing Record 32 of Set 7 | haapiti
# Processing Record 33 of Set 7 | novobiryusinskiy
# Processing Record 34 of Set 7 | hohhot
# Processing Record 35 of Set 7 | beyneu
# Processing Record 36 of Set 7 | cidreira
# Processing Record 37 of Set 7 | marawi
# Processing Record 38 of Set 7 | grand-santi
# Processing Record 39 of Set 7 | mnogovershinnyy
# Processing Record 40 of Set 7 | shuya
# Processing Record 41 of Set 7 | aksarayskiy
# Processing Record 42 of Set 7 | tarudant
# City not found. Skipping...
# Processing Record 43 of Set 7 | rajmahal
# Processing Record 44 of Set 7 | marsala
# Processing Record 45 of Set 7 | cockburn town
# Processing Record 46 of Set 7 | kapoeta
# Processing Record 47 of Set 7 | namatanai
# Processing Record 48 of Set 7 | muli
# Processing Record 49 of Set 7 | sentyabrskiy
# City not found. Skipping...
# Processing Record 50 of Set 7 | ribeira grande
# Processing Record 1 of Set 8 | saleaula
# City not found. Skipping...
# Processing Record 2 of Set 8 | ulaangom
# Processing Record 3 of Set 8 | uralets
# Processing Record 4 of Set 8 | vostok
# Processing Record 5 of Set 8 | tual
# Processing Record 6 of Set 8 | saint-louis
# Processing Record 7 of Set 8 | nabire
# Processing Record 8 of Set 8 | tabas
# Processing Record 9 of Set 8 | ventspils
# Processing Record 10 of Set 8 | pahrump
# Processing Record 11 of Set 8 | waipawa
# Processing Record 12 of Set 8 | uchkeken
# Processing Record 13 of Set 8 | richmond
# Processing Record 14 of Set 8 | anchorage
# Processing Record 15 of Set 8 | antropovo
# Processing Record 16 of Set 8 | kisangani
# Processing Record 17 of Set 8 | nuuk
# Processing Record 18 of Set 8 | san vicente
# Processing Record 19 of Set 8 | malakal
# Processing Record 20 of Set 8 | bukachacha
# Processing Record 21 of Set 8 | itupiranga
# Processing Record 22 of Set 8 | bethel
# Processing Record 23 of Set 8 | tuatapere
# Processing Record 24 of Set 8 | mersing
# Processing Record 25 of Set 8 | coihaique
# Processing Record 26 of Set 8 | nyurba
# Processing Record 27 of Set 8 | moerai
# Processing Record 28 of Set 8 | meulaboh
# Processing Record 29 of Set 8 | casas grandes
# Processing Record 30 of Set 8 | avera
# Processing Record 31 of Set 8 | batagay
# Processing Record 32 of Set 8 | lashio
# Processing Record 33 of Set 8 | mugumu
# Processing Record 34 of Set 8 | bonavista
# Processing Record 35 of Set 8 | santa rosa
# Processing Record 36 of Set 8 | ondjiva
# Processing Record 37 of Set 8 | khudumelapye
# Processing Record 38 of Set 8 | cururupu
# Processing Record 39 of Set 8 | sabya
# Processing Record 40 of Set 8 | milkovo
# Processing Record 41 of Set 8 | bira
# Processing Record 42 of Set 8 | lodingen
# Processing Record 43 of Set 8 | koboldo
# City not found. Skipping...
# Processing Record 44 of Set 8 | yumen
# Processing Record 45 of Set 8 | mattru
# Processing Record 46 of Set 8 | port lincoln
# Processing Record 47 of Set 8 | pandan
# Processing Record 48 of Set 8 | bargal
# City not found. Skipping...
# Processing Record 49 of Set 8 | pauri
# Processing Record 50 of Set 8 | lebu
# Processing Record 1 of Set 9 | boden
# Processing Record 2 of Set 9 | finnsnes
# Processing Record 3 of Set 9 | lompoc
# Processing Record 4 of Set 9 | laa
# Processing Record 5 of Set 9 | tigil
# Processing Record 6 of Set 9 | saint george
# Processing Record 7 of Set 9 | wakkanai
# Processing Record 8 of Set 9 | usinsk
# Processing Record 9 of Set 9 | pueblo
# Processing Record 10 of Set 9 | la ronge
# Processing Record 11 of Set 9 | marcona
# City not found. Skipping...
# Processing Record 12 of Set 9 | kalach-na-donu
# Processing Record 13 of Set 9 | makungu
# Processing Record 14 of Set 9 | hirado
# Processing Record 15 of Set 9 | leningradskiy
# Processing Record 16 of Set 9 | bafra
# Processing Record 17 of Set 9 | nouadhibou
# Processing Record 18 of Set 9 | partizanskoye
# Processing Record 19 of Set 9 | ayer molek
# Processing Record 20 of Set 9 | klyuchi
# Processing Record 21 of Set 9 | bolungarvik
# City not found. Skipping...
# Processing Record 22 of Set 9 | port pirie
# Processing Record 23 of Set 9 | canico
# Processing Record 24 of Set 9 | ilulissat
# Processing Record 25 of Set 9 | lishan
# Processing Record 26 of Set 9 | wahiawa
# Processing Record 27 of Set 9 | baruun-urt
# Processing Record 28 of Set 9 | the valley
# Processing Record 29 of Set 9 | atascocita
# Processing Record 30 of Set 9 | palembang
# Processing Record 31 of Set 9 | imbituba
# Processing Record 32 of Set 9 | murgab
# Processing Record 33 of Set 9 | noyabrsk
# Processing Record 34 of Set 9 | morondava
# Processing Record 35 of Set 9 | villarrubia de los ojos
# Processing Record 36 of Set 9 | adrar
# Processing Record 37 of Set 9 | himora
# City not found. Skipping...
# Processing Record 38 of Set 9 | nemuro
# Processing Record 39 of Set 9 | anadyr
# Processing Record 40 of Set 9 | tiksi
# Processing Record 41 of Set 9 | vanavara
# Processing Record 42 of Set 9 | mount pleasant
# Processing Record 43 of Set 9 | beloha
# Processing Record 44 of Set 9 | roma
# Processing Record 45 of Set 9 | ohaba
# Processing Record 46 of Set 9 | lucapa
# Processing Record 47 of Set 9 | shimoda
# Processing Record 48 of Set 9 | te anau
# Processing Record 49 of Set 9 | talnakh
# Processing Record 50 of Set 9 | kieta
# Processing Record 1 of Set 10 | halalo
# City not found. Skipping...
# Processing Record 2 of Set 10 | nadym
# Processing Record 3 of Set 10 | ola
# Processing Record 4 of Set 10 | chapais
# Processing Record 5 of Set 10 | hare bay
# Processing Record 6 of Set 10 | omsukchan
# Processing Record 7 of Set 10 | penzance
# Processing Record 8 of Set 10 | pangnirtung
# Processing Record 9 of Set 10 | auki
# Processing Record 10 of Set 10 | abu kamal
# Processing Record 11 of Set 10 | tateyama
# Processing Record 12 of Set 10 | balabac
# Processing Record 13 of Set 10 | juifang
# City not found. Skipping...
# Processing Record 14 of Set 10 | quang ngai
# Processing Record 15 of Set 10 | sarangani
# Processing Record 16 of Set 10 | barranca
# Processing Record 17 of Set 10 | gangotri
# City not found. Skipping...
# Processing Record 18 of Set 10 | kollam
# Processing Record 19 of Set 10 | souillac
# Processing Record 20 of Set 10 | alotau
# City not found. Skipping...
# Processing Record 21 of Set 10 | valley city
# Processing Record 22 of Set 10 | changji
# Processing Record 23 of Set 10 | abu zabad
# Processing Record 24 of Set 10 | carutapera
# Processing Record 25 of Set 10 | buraydah
# Processing Record 26 of Set 10 | coquimbo
# Processing Record 27 of Set 10 | guthrie
# Processing Record 28 of Set 10 | erenhot
# Processing Record 29 of Set 10 | san carlos
# Processing Record 30 of Set 10 | ballitoville
# Processing Record 31 of Set 10 | qunduz
# Processing Record 32 of Set 10 | christchurch
# Processing Record 33 of Set 10 | worland
# Processing Record 34 of Set 10 | conchas
# Processing Record 35 of Set 10 | new iberia
# Processing Record 36 of Set 10 | gimli
# Processing Record 37 of Set 10 | trairi
# Processing Record 38 of Set 10 | bacuit
# City not found. Skipping...
# Processing Record 39 of Set 10 | batagay-alyta
# Processing Record 40 of Set 10 | sedelnikovo
# City not found. Skipping...
# Processing Record 41 of Set 10 | beringovskiy
# Processing Record 42 of Set 10 | masvingo
# Processing Record 43 of Set 10 | port keats
# Processing Record 44 of Set 10 | alyangula
# Processing Record 45 of Set 10 | lata
# Processing Record 46 of Set 10 | kaitangata
# Processing Record 47 of Set 10 | kingman
# Processing Record 48 of Set 10 | san quintin
# Processing Record 49 of Set 10 | colares
# Processing Record 50 of Set 10 | louis trichardt
# Processing Record 1 of Set 11 | iwanai
# Processing Record 2 of Set 11 | vestmanna
# Processing Record 3 of Set 11 | panguna
# Processing Record 4 of Set 11 | moranbah
# Processing Record 5 of Set 11 | ranot
# Processing Record 6 of Set 11 | salinopolis
# Processing Record 7 of Set 11 | guarapari
# Processing Record 8 of Set 11 | cody
# Processing Record 9 of Set 11 | sola
# Processing Record 10 of Set 11 | grand island
# Processing Record 11 of Set 11 | taksimo
# Processing Record 12 of Set 11 | kombotion
# City not found. Skipping...
# Processing Record 13 of Set 11 | byron bay
# Processing Record 14 of Set 11 | sahuaripa
# Processing Record 15 of Set 11 | ornskoldsvik
# Processing Record 16 of Set 11 | nuevo progreso
# Processing Record 17 of Set 11 | pinerolo
# Processing Record 18 of Set 11 | bur gabo
# City not found. Skipping...
# Processing Record 19 of Set 11 | half moon bay
# Processing Record 20 of Set 11 | qaqortoq
# Processing Record 21 of Set 11 | dolbeau
# City not found. Skipping...
# Processing Record 22 of Set 11 | keskin
# Processing Record 23 of Set 11 | tonekabon
# Processing Record 24 of Set 11 | talcahuano
# Processing Record 25 of Set 11 | kresttsy
# Processing Record 26 of Set 11 | tres arroyos
# Processing Record 27 of Set 11 | tsienyane
# City not found. Skipping...
# Processing Record 28 of Set 11 | okmulgee
# Processing Record 29 of Set 11 | rolim de moura
# City not found. Skipping...
# Processing Record 30 of Set 11 | bonthe
# Processing Record 31 of Set 11 | tara
# Processing Record 32 of Set 11 | tuy hoa
# Processing Record 33 of Set 11 | biltine
# Processing Record 34 of Set 11 | les cayes
# Processing Record 35 of Set 11 | neuquen
# Processing Record 36 of Set 11 | iberia
# Processing Record 37 of Set 11 | miranda
# Processing Record 38 of Set 11 | evensk
# Processing Record 39 of Set 11 | port hedland
# Processing Record 40 of Set 11 | tarnow
# Processing Record 41 of Set 11 | dudinka
# Processing Record 42 of Set 11 | marienburg
# Processing Record 43 of Set 11 | pravia
# Processing Record 44 of Set 11 | mishkino
# Processing Record 45 of Set 11 | fukue
# Processing Record 46 of Set 11 | padang
# Processing Record 47 of Set 11 | iskateley
# Processing Record 48 of Set 11 | anloga
# Processing Record 49 of Set 11 | krasnoyarsk-45
# City not found. Skipping...
# Processing Record 50 of Set 11 | lalmohan
# Processing Record 1 of Set 12 | khani
# Processing Record 2 of Set 12 | phan rang
# City not found. Skipping...
# Processing Record 3 of Set 12 | mikhaylovka
# Processing Record 4 of Set 12 | saint-georges
# Processing Record 5 of Set 12 | poum
# Processing Record 6 of Set 12 | altamira
# Processing Record 7 of Set 12 | nador
# Processing Record 8 of Set 12 | cabedelo
# Processing Record 9 of Set 12 | erdenet
# Processing Record 10 of Set 12 | ayan
# Processing Record 11 of Set 12 | troina
# Processing Record 12 of Set 12 | irpa irpa
# Processing Record 13 of Set 12 | medyn
# Processing Record 14 of Set 12 | palm beach
# Processing Record 15 of Set 12 | bandarbeyla
# Processing Record 16 of Set 12 | paulo afonso
# Processing Record 17 of Set 12 | surt
# Processing Record 18 of Set 12 | tyrma
# Processing Record 19 of Set 12 | ulaanbaatar
# Processing Record 20 of Set 12 | jamui
# Processing Record 21 of Set 12 | san carlos de bariloche
# Processing Record 22 of Set 12 | novyy urgal
# Processing Record 23 of Set 12 | kuala pilah
# Processing Record 24 of Set 12 | ahipara
# Processing Record 25 of Set 12 | saint-joseph
# Processing Record 26 of Set 12 | ati
# Processing Record 27 of Set 12 | westport
# Processing Record 28 of Set 12 | sarkand
# Processing Record 29 of Set 12 | alihe
# Processing Record 30 of Set 12 | shelburne
# Processing Record 31 of Set 12 | casma
# Processing Record 32 of Set 12 | uporovo
# Processing Record 33 of Set 12 | ozinki
# Processing Record 34 of Set 12 | katangli
# Processing Record 35 of Set 12 | tunduru
# City not found. Skipping...
# Processing Record 36 of Set 12 | pangoa
# Processing Record 37 of Set 12 | phan thiet
# Processing Record 38 of Set 12 | olafsvik
# Processing Record 39 of Set 12 | mareeba
# Processing Record 40 of Set 12 | pueblo nuevo
# Processing Record 41 of Set 12 | natal
# Processing Record 42 of Set 12 | tsumeb
# Processing Record 43 of Set 12 | staryy nadym
# Processing Record 44 of Set 12 | babanusah
# City not found. Skipping...
# Processing Record 45 of Set 12 | price
# Processing Record 46 of Set 12 | bambanglipuro
# Processing Record 47 of Set 12 | pathein
# Processing Record 48 of Set 12 | riberalta
# Processing Record 49 of Set 12 | vyartsilya
# Processing Record 50 of Set 12 | mogadishu
# Processing Record 1 of Set 13 | sile
# Processing Record 2 of Set 13 | cabo san lucas
# Processing Record 3 of Set 13 | momcilgrad
# City not found. Skipping...
# Processing Record 4 of Set 13 | grand river south east
# City not found. Skipping...
# Processing Record 5 of Set 13 | namuac
# Processing Record 6 of Set 13 | wanning
# Processing Record 7 of Set 13 | igede
# Processing Record 8 of Set 13 | boyolangu
# Processing Record 9 of Set 13 | pathanamthitta
# Processing Record 10 of Set 13 | pochutla
# Processing Record 11 of Set 13 | banepa
# Processing Record 12 of Set 13 | pyaozerskiy
# Processing Record 13 of Set 13 | qostanay
# Processing Record 14 of Set 13 | oranjemund
# Processing Record 15 of Set 13 | sussex
# Processing Record 16 of Set 13 | majene
# Processing Record 17 of Set 13 | takikawa
# Processing Record 18 of Set 13 | santa vitoria
# Processing Record 19 of Set 13 | el seibo
# Processing Record 20 of Set 13 | samarai
# Processing Record 21 of Set 13 | taunggyi
# Processing Record 22 of Set 13 | khormuj
# City not found. Skipping...
# Processing Record 23 of Set 13 | osakarovka
# Processing Record 24 of Set 13 | armacao dos buzios
# City not found. Skipping...
# Processing Record 25 of Set 13 | columbia
# Processing Record 26 of Set 13 | hofn
# Processing Record 27 of Set 13 | liusha
# Processing Record 28 of Set 13 | chimore
# Processing Record 29 of Set 13 | svetlyy
# Processing Record 30 of Set 13 | humaita
# Processing Record 31 of Set 13 | allingabro
# Processing Record 32 of Set 13 | naze
# Processing Record 33 of Set 13 | tiruvottiyur
# City not found. Skipping...
# Processing Record 34 of Set 13 | port blair
# Processing Record 35 of Set 13 | igarape-miri
# City not found. Skipping...
# Processing Record 36 of Set 13 | silale
# Processing Record 37 of Set 13 | marivan
# Processing Record 38 of Set 13 | bilibino
# Processing Record 39 of Set 13 | bouca
# Processing Record 40 of Set 13 | chissamba
# Processing Record 41 of Set 13 | uk
# City not found. Skipping...
# Processing Record 42 of Set 13 | makakilo city
# Processing Record 43 of Set 13 | mugur-aksy
# Processing Record 44 of Set 13 | linjiang
# Processing Record 45 of Set 13 | isangel
# Processing Record 46 of Set 13 | kitimat
# Processing Record 47 of Set 13 | okha
# Processing Record 48 of Set 13 | opole
# Processing Record 49 of Set 13 | khonuu
# City not found. Skipping...
# Processing Record 50 of Set 13 | harnosand
# Processing Record 1 of Set 14 | stornoway
# Processing Record 2 of Set 14 | arvika
# Processing Record 3 of Set 14 | maykain
# City not found. Skipping...
# Processing Record 4 of Set 14 | lubango
# Processing Record 5 of Set 14 | bacolod
# Processing Record 6 of Set 14 | antofagasta
# Processing Record 7 of Set 14 | karratha
# Processing Record 8 of Set 14 | djougou
# Processing Record 9 of Set 14 | pokrovka
# Processing Record 10 of Set 14 | yulara
# Processing Record 11 of Set 14 | pagondas
# City not found. Skipping...
# Processing Record 12 of Set 14 | rancharia
# Processing Record 13 of Set 14 | lethem
# Processing Record 14 of Set 14 | mahibadhoo
# Processing Record 15 of Set 14 | buritizeiro
# Processing Record 16 of Set 14 | patratu
# City not found. Skipping...
# Processing Record 17 of Set 14 | udachnyy
# Processing Record 18 of Set 14 | mae sot
# Processing Record 19 of Set 14 | zyryanka
# Processing Record 20 of Set 14 | shihezi
# Processing Record 21 of Set 14 | pomabamba
# Processing Record 22 of Set 14 | quatre cocos
# Processing Record 23 of Set 14 | ambilobe
# Processing Record 24 of Set 14 | ternate
# Processing Record 25 of Set 14 | high rock
# Processing Record 26 of Set 14 | dire dawa
# Processing Record 27 of Set 14 | rio gallegos
# Processing Record 28 of Set 14 | bosobolo
# Processing Record 29 of Set 14 | kaya
# Processing Record 30 of Set 14 | murray bridge
# Processing Record 31 of Set 14 | turukhansk
# Processing Record 32 of Set 14 | thakurganj
# Processing Record 33 of Set 14 | birin
# Processing Record 34 of Set 14 | scarborough
# Processing Record 35 of Set 14 | paramonga
# Processing Record 36 of Set 14 | aberdeen
# Processing Record 37 of Set 14 | sovetskiy
# Processing Record 38 of Set 14 | tallahassee
# Processing Record 39 of Set 14 | srirampur
# Processing Record 40 of Set 14 | aloleng
# Processing Record 41 of Set 14 | hanna
# Processing Record 42 of Set 14 | kasane
# Processing Record 43 of Set 14 | malinyi
# Processing Record 44 of Set 14 | severo-yeniseyskiy
# Processing Record 45 of Set 14 | bilma
# Processing Record 46 of Set 14 | foki
# Processing Record 47 of Set 14 | hermiston
# Processing Record 48 of Set 14 | mrirt
# City not found. Skipping...
# Processing Record 49 of Set 14 | roald
# Processing Record 50 of Set 14 | maigo
# Processing Record 1 of Set 15 | sangamner
# Processing Record 2 of Set 15 | hailar
# Processing Record 3 of Set 15 | savelugu
# Processing Record 4 of Set 15 | hammond
# Processing Record 5 of Set 15 | oktyabrskiy
# Processing Record 6 of Set 15 | kloulklubed
# Processing Record 7 of Set 15 | kaeo
# Processing Record 8 of Set 15 | ngukurr
# City not found. Skipping...
# Processing Record 9 of Set 15 | dingle
# Processing Record 10 of Set 15 | teya
# Processing Record 11 of Set 15 | puerto carreno
# Processing Record 12 of Set 15 | kropotkin
# Processing Record 13 of Set 15 | upornaya
# Processing Record 14 of Set 15 | mountain home
# Processing Record 15 of Set 15 | sokolka
# Processing Record 16 of Set 15 | jiangyou
# Processing Record 17 of Set 15 | durban
# Processing Record 18 of Set 15 | naica
# Processing Record 19 of Set 15 | chivay
# Processing Record 20 of Set 15 | mizan teferi
# Processing Record 21 of Set 15 | kununurra
# Processing Record 22 of Set 15 | chernaya kholunitsa
# Processing Record 23 of Set 15 | namtsy
# Processing Record 24 of Set 15 | kantang
# Processing Record 25 of Set 15 | joshimath
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 661

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#                  City Country      Lat       Lng  Max Temp  Humidity  \
# 0           Jamestown      US  42.0970  -79.2353     31.01        70
# 1              Barrow      US  71.2906 -156.7887     32.50        87
# 2             Kahului      US  20.8947 -156.4700     82.98        80
# 3           Cape Town      ZA -33.9258   18.4232     59.92        75
# 4              Talara      PE  -4.5772  -81.2719     64.76        88
# 5           Mahebourg      MU -20.4081   57.7000     69.26        88
# 6             Hualmay      PE -11.0964  -77.6139     64.45        83
# 7           Busselton      AU -33.6500  115.3333     53.89        68
# 8  Comodoro Rivadavia      AR -45.8667  -67.5000     71.46        35
# 9            Klaksvik      FO  62.2266   -6.5890     47.32        83
#
#    Cloudiness  Wind Speed Current Description
# 0          97       11.99     overcast clouds
# 1         100        9.98     overcast clouds
# 2          24        8.99          few clouds
# 3           0        8.05           clear sky
# 4          94       13.33     overcast clouds
# 5          20        6.91          few clouds
# 6          46        7.16    scattered clouds
# 7          87       20.94          light rain
# 8           0       11.50           clear sky
# 9          88       35.90          light rain

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Country', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Current Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]

# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[new_column_order]

# Display sample data
city_data_df.head(10)
# Out:
#                  City Country      Lat       Lng  Max Temp  Humidity  \
# 0           Jamestown      US  42.0970  -79.2353     31.01        70
# 1              Barrow      US  71.2906 -156.7887     32.50        87
# 2             Kahului      US  20.8947 -156.4700     82.98        80
# 3           Cape Town      ZA -33.9258   18.4232     59.92        75
# 4              Talara      PE  -4.5772  -81.2719     64.76        88
# 5           Mahebourg      MU -20.4081   57.7000     69.26        88
# 6             Hualmay      PE -11.0964  -77.6139     64.45        83
# 7           Busselton      AU -33.6500  115.3333     53.89        68
# 8  Comodoro Rivadavia      AR -45.8667  -67.5000     71.46        35
# 9            Klaksvik      FO  62.2266   -6.5890     47.32        83
#
#    Cloudiness  Wind Speed Current Description
# 0          97       11.99     overcast clouds
# 1         100        9.98     overcast clouds
# 2          24        8.99          few clouds
# 3           0        8.05           clear sky
# 4          94       13.33     overcast clouds
# 5          20        6.91          few clouds
# 6          46        7.16    scattered clouds
# 7          87       20.94          light rain
# 8           0       11.50           clear sky
# 9          88       35.90          light rain

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "../Weather_Database/WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file, index_label="City_ID")
